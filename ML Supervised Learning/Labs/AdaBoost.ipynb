# %% [markdown]
# # Spam dataset with ensemble methods

# %%
# !git clone https://github.com/s7s/machine_learning_1.git
# %cd  machine_learning_1/ensemble_methods
# Out:
# Cloning into 'machine_learning_1'...
# remote: Enumerating objects: 417, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 417 (delta 46), reused 27 (delta 27), pack-reused 358 (from 2)
# Receiving objects: 100% (417/417), 43.28 MiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (217/217), done.
# /content/machine_learning_1/ensemble_methods

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import utils

from sklearn import tree

np.random.seed(0)

# %% [markdown]
# # The spam email dataset

# %%
emails = np.array([
    [7,8,1],
    [3,2,0],
    [8,4,1],
    [2,6,0],
    [6,5,1],
    [9,6,1],
    [8,5,0],
    [7,1,0],
    [1,9,1],
    [4,7,0],
    [1,3,0],
    [3,10,1],
    [2,2,1],
    [9,3,0],
    [5,3,0],
    [10,1,0],
    [5,9,1],
    [10,8,1],
])
spam_dataset = pd.DataFrame(data=emails, columns=["Lottery", "Sale", "Spam"])
spam_dataset
# Out:
#     Lottery  Sale  Spam
# 0         7     8     1
# 1         3     2     0
# 2         8     4     1
# 3         2     6     0
# 4         6     5     1
# 5         9     6     1
# 6         8     5     0
# 7         7     1     0
# 8         1     9     1
# 9         4     7     0
# 10        1     3     0
# 11        3    10     1
# 12        2     2     1
# 13        9     3     0
# 14        5     3     0
# 15       10     1     0
# 16        5     9     1
# 17       10     8     1

# %%
features = spam_dataset[['Lottery', 'Sale']]
labels = spam_dataset['Spam']
utils.plot_points(features, labels)

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
# Set the random_state so that we always get the same results
# use adaboost classifier with 6 estimator
adaboost_classifier = AdaBoostClassifier(random_state = None , n_estimators = 6)
adaboost_classifier.fit(features,labels)
adaboost_classifier.score(features, labels)
# Out:
# 0.7777777777777778

# %%
utils.plot_model(features, labels, adaboost_classifier)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
estimators = adaboost_classifier.estimators_
for estimator in estimators:
    utils.plot_model(features, labels, estimator)
    plt.show()
