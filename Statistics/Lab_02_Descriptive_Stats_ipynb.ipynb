# %% [markdown]
# ### 911 call data from [Kaggle](https://www.kaggle.com/mchirico/montcoalert).
# #### The data contains the following fields:
#
# * lat : Latitude
# * lng:  Longitude
# * desc: Description of the Emergency Call
# * zip:  Zipcode
# * title:Title
# * timeStamp: YYYY-MM-DD HH:MM:SS
# * twp: Township
# * addr: Address
# * e: Dummy variable (always 1)

# %% [markdown]
# ### 1 - Import numpy, pandas and visualization libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2 - Read in the 911.csv file as a dataframe

# %%
df = pd.read_csv("911.csv")

# %% [markdown]
# ### 3 - Check the info() of the df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %% [markdown]
# ### 4 - Check the head of df

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %% [markdown]
# ### 5 - Get the descriptive statistics of the df

# %%
df.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %% [markdown]
# ### Answer the following questions:

# %% [markdown]
# #### 6 - What are the top 5 zipcodes for 911 calls?
# ##### Hint: Use value_counts()

# %%
top_5_zip=df["zip"].value_counts()
print(top_5_zip.iloc[:5])
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: count, dtype: int64

# %%
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %% [markdown]
# #### 7 - What are the top 5 townships (twp) for 911 calls?
# ##### Visualize your results.

# %%
top_5_twp=df['twp'].value_counts()
top_5_twp = top_5_twp[:5]
print(top_5_twp)
# Out:
# twp
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: count, dtype: int64

# %%
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %%
#your insights goes here
#Lower Merion has the most 911 calls , which might show that there's alot of crime there 
#Cheltenham has the lowest number of calls compared to the others

# %%
towns = top_5_twp.index     
values = top_5_twp.values   
sns.barplot(x=towns, y=values,hue=towns)
plt.ylabel("Count")
plt.xlabel("Top 5 townships for 911 calls")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8 - Take a look at the 'title' column, how many unique title codes are there?
# ####9 -  What are those titles?
# ##### Hint: use unique() and nunique()

# %%
title=df["title"].unique()
print(len(title))
# Out:
# 110

# %%
# Out:
# 110

# %%
df["title"].unique()
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
# ...

# %%
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
# ...

# %% [markdown]
# ## 10 - Creating new features

# %% [markdown]
# - In the titles column there are "Reasons/Departments" specified before the title code.
# - These are <b>EMS, Fire, and Traffic</b>.
# - Use .apply() with a custom lambda expression to create a new column called "Reason" that contains these string values.
# - For example, if the title column value is <b>EMS: BACK PAINS/INJURY</b> , the Reason column value would be <b>EMS</b>.
# ##### Hint: You can use split() function in the lambda expression.

# %%
df["Reason"] = df["title"].apply(lambda x: x.split(":")[0])
#apply goes through the column value by value and applies the split on it , then takes the first part after splitting 
#That is the part before the :

# %%
df[["Reason"]]
#df["Reason"].to_frame()
# Out:
#         Reason
# 0          EMS
# 1          EMS
# 2         Fire
# 3          EMS
# 4          EMS
# ...        ...
# 99487  Traffic
# 99488  Traffic
# 99489      EMS
# 99490      EMS
# 99491  Traffic
#
# [99492 rows x 1 columns]

# %%
# Out:
#         Reason
# 0          EMS
# 1          EMS
# 2         Fire
# 3          EMS
# 4          EMS
# ...        ...
# 99487  Traffic
# 99488  Traffic
# 99489      EMS
# 99490      EMS
# 99491  Traffic
#
# [99492 rows x 1 columns]

# %% [markdown]
# ### 11 - What is the most common Reason for a 911 call based off of this new column?

# %%
common_reason=df["Reason"].value_counts()
print(common_reason)
# Out:
# Reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %%
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %% [markdown]
# ### 12 - Create a pie chart to see the percentage of each reason.

# %%
plt.pie(x=common_reason,labels=common_reason.index,autopct='%1.1f%%')
plt.legend()
plt.show()
#Insights
#Emergency medical service(EMS) marks as the most common reason for calling 911

# %% [markdown]
# ###13 - Now use seaborn to create a countplot of 911 calls by Reason.

# %%
sns.countplot(x=df["Reason"],hue=df["Reason"])
# Out:
# <Axes: xlabel='Reason', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='count'>

# %% [markdown]
# ### 14 - Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) to convert the column from strings to DateTime objects.

# %%
df["timeStamp"]=pd.to_datetime(df['timeStamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  datetime64[ns]
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
#  9   Reason     99492 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 7.6+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  datetime64[ns]
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
#  9   Reason     99492 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 7.6+ MB

# %% [markdown]
# ### 15 - Create the following new columns:
# - Now that the timestamp column are actually DateTime objects.
# - use <b>.apply()</b> to create 3 new columns called Hour, Month, and Day of Week.
# - You will create these columns based off of the timeStamp column.

# %%
df["Hour"] = df["timeStamp"].apply(lambda x: x.hour)
df["Month"] = df["timeStamp"].apply(lambda x: x.month)
df["Day Of Week"] = df["timeStamp"].apply(lambda x: x.weekday())
#as the day is an int 0 is Monday and so on 
#if asked for the week day itself use day_name
print(df["Day Of Week"])
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 99487    2
# 99488    2
# 99489    2
# 99490    2
# 99491    2
# Name: Day Of Week, Length: 99492, dtype: int64

# %%
df = df.drop("DayOfWeek", axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lat          99492 non-null  float64
#  1   lng          99492 non-null  float64
#  2   desc         99492 non-null  object
#  3   zip          86637 non-null  float64
#  4   title        99492 non-null  object
#  5   timeStamp    99492 non-null  datetime64[ns]
#  6   twp          99449 non-null  object
#  7   addr         98973 non-null  object
#  8   e            99492 non-null  int64
#  9   Reason       99492 non-null  object
#  10  Hour         99492 non-null  int64
#  11  Month        99492 non-null  int64
#  12  Day Of Week  99492 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 9.9+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   lat          99492 non-null  float64
#  1   lng          99492 non-null  float64
#  2   desc         99492 non-null  object
#  3   zip          86637 non-null  float64
#  4   title        99492 non-null  object
#  5   timeStamp    99492 non-null  datetime64[ns]
#  6   twp          99449 non-null  object
#  7   addr         98973 non-null  object
#  8   e            99492 non-null  int64
#  9   Reason       99492 non-null  object
#  10  Hour         99492 non-null  int64
#  11  Month        99492 non-null  int64
#  12  Day of Week  99492 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 9.9+ MB

# %%
#print(df["Day Of Week"])
df[["Hour", "Month", "Day Of Week"]]
# Out:
#        Hour  Month  Day Of Week
# 0        17     12            3
# 1        17     12            3
# 2        17     12            3
# 3        17     12            3
# 4        17     12            3
# ...     ...    ...          ...
# 99487    11      8            2
# 99488    11      8            2
# 99489    11      8            2
# 99490    11      8            2
# 99491    11      8            2
#
# [99492 rows x 3 columns]

# %%
# Out:
#        Hour  Month  Day of Week
# 0        17     12            3
# 1        17     12            3
# 2        17     12            3
# 3        17     12            3
# 4        17     12            3
# ...     ...    ...          ...
# 99487    11      8            2
# 99488    11      8            2
# 99489    11      8            2
# 99490    11      8            2
# 99491    11      8            2
#
# [99492 rows x 3 columns]

# %% [markdown]
# ### 16 - Use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column.

# %%
#your insights goes here
#MThe highest reason is for 911 calls is EMS occuring on the days of Monday , Tuesday , and Friday 
#Highest traffic incident calls are during the weekdays , which might show that people are rushing to their work 
#Or picking/dropping off their kids to school

# %%
sns.countplot(x=df["Day Of Week"],hue=df["Reason"])
# Out:
# <Axes: xlabel='Day Of Week', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='Day of Week', ylabel='count'>

# %% [markdown]
# ### 17 - Use map function to change the Day of Week from numbers to actual days and replot.

# %%
days_dict={0:"Thrus",
           1:"Fri",
           2:"Sat",
           3:"Sun",
           4:"Mon",
           5:"Tues",
           6:"Wednes"}

order = ["Thrus","Fri","Sat","Sun","Mon","Tues","Wednes"] #Does order actually change the order ?

sns.countplot(x=df["Day Of Week"].map(days_dict),hue=df["Reason"],order=order)
# Out:
# <Axes: xlabel='Day Of Week', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='Day of Week', ylabel='count'>

# %% [markdown]
# ### 18 - Use seaborn to create a countplot of the Month column with the hue based off of the Reason column.

# %%
#your insights goes here
#The highest number of EMS calls are in months January and July which have roughly the same volume.
#This shows a pattern where medical emergencies increase during holiday months,
# such as New Year’s celebrations in January and Independence Day activities in July.
#This shows that people may be more prone to health issues during festive periods.
#Cant train on this dta as the data from 9-11 is missing

# %%
sns.countplot(x=df["Month"],hue=df["Reason"])
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>
