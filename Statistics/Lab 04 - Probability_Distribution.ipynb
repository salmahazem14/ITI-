# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats as st
# %matplotlib inline

# %%
from scipy.stats import zscore
from scipy.stats import norm
from scipy.stats import binom

import numpy as np
#data = np.random.binomial(n=,p=,size=)

p_arr = binom.pmf(x_arr,n,p)

mean, var= binom.stats(n, p, moments='mv')

#scores = random.normal(mu,std, size=)
#zscores = zscore(scores)


norm.ppf(0.95,loc=mu,scale=std)
# Out:
#   Cell In[27], line 11
#     scores = random.normal(mu,std, size=)
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## If you want to see the same results as here use np.random.seed(42)

# %% [markdown]
# ## Bernoulli

# %% [markdown]
# ### Create random sample data from a Bernoulli distribution with p=0.6 and size=1000.
# ### For the created data perform the following:
# - Count plot.
# - Hist plot with y-axis represents the proportion.
# - Calculate mean, variance, standard deviation, median, and mode.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)

data = np.random.binomial(n=1,p=0.6,size=100)
sns.countplot(x=data , hue=data)
# Out:
# <Axes: ylabel='count'>

# %%
np.random.seed(42)
sns.histplot(x=data,hue=data)
# Out:
# <Axes: ylabel='Count'>

# %%
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Out:
# <AxesSubplot:ylabel='Proportion'>

# %%
print(f"Mean : {data.mean()}") #if data is 0 and 1 , the mean is the prop of success
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.63
# Var : 0.23310000000000003
# Std : 0.48280430818293246
# Median : 1.0
# Mode : ModeResult(mode=np.int32(1), count=np.int64(63))

# %%
# Out:
# Mean: 0.613
# Var: 0.237231
# Std: 0.4870636508712183
# Median: 1.0
# Mode: ModeResult(mode=array([1]), count=array([613]))

# %% [markdown]
# ### Use scipy.stats.bernoulli.pmf
# - Calculate the probabilities of success and failure.

# %%
from scipy.stats import bernoulli
p=0.6
print("P(1):", bernoulli.pmf(1, p))
print("P(0):", bernoulli.pmf(0, p))
# Out:
# P(1): 0.6
# P(0): 0.4000000000000001

# %%
# Out:
# P(1): 0.6
# P(0): 0.4

# %% [markdown]
# ### Repeat with other values of probability of success.
# ##### The following results uses p=0.5, p=0.9, and p=0.2

# %%
# p = 0.5
np.random.seed(42)

data = np.random.binomial(n=1,p=0.5,size=100)
sns.countplot(x=data , hue=data)
# Out:
# <Axes: ylabel='count'>

# %%
# p = 0.9
np.random.seed(42)

data = np.random.binomial(n=1,p=0.9,size=100)
sns.countplot(x=data , hue=data)

print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.91
# Var : 0.08190000000000001
# Std : 0.2861817604250837
# Median : 1.0
# Mode : ModeResult(mode=np.int32(1), count=np.int64(91))

# %%
# p = 0.9
# Out:
# Mean: 0.9
# Var: 0.09
# Std: 0.3
# Median: 1.0
# Mode: ModeResult(mode=array([1]), count=array([900]))
# P(1): 0.9
# P(0): 0.09999999999999998

# %%
data = np.random.binomial(n=1,p=0.9,size=100)
sns.histplot(x=data , hue=data)
# Out:
# <Axes: ylabel='Count'>

# %%
# p = 0.9
np.random.seed(42)
data = np.random.binomial(n=1,p=0.9,size=100)
sns.countplot(x=data , hue=data)

print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.91
# Var : 0.08190000000000001
# Std : 0.2861817604250837
# Median : 1.0
# Mode : ModeResult(mode=np.int32(1), count=np.int64(91))

# %%
np.random.seed(42)
data = np.random.binomial(n=1,p=0.2,size=100)
sns.countplot(x=data , hue=data)
print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.18
# Var : 0.14760000000000004
# Std : 0.38418745424597095
# Median : 0.0
# Mode : ModeResult(mode=np.int32(0), count=np.int64(82))

# %%
# p = 0.2
# Out:
# Mean: 0.199
# Var: 0.159399
# Std: 0.399248043201216
# Median: 0.0
# Mode: ModeResult(mode=array([0]), count=array([801]))
# P(1): 0.2
# P(0): 0.8

# %% [markdown]
# ### Repeat with p=0.5 and sample sizes  50 and 50000.
# ##### Observe the difference in the meand value

# %%
np.random.seed(42)
data = np.random.binomial(n=1,p=0.5,size=50)
sns.countplot(x=data , hue=data)
print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.44
# Var : 0.24640000000000004
# Std : 0.4963869458396343
# Median : 0.0
# Mode : ModeResult(mode=np.int32(0), count=np.int64(28))

# %%
# p = 0.5, size = 50
# Out:
# Mean: 0.44
# Var: 0.24640000000000004
# Std: 0.4963869458396343
# Median: 0.0
# Mode: ModeResult(mode=array([0]), count=array([28]))

# %%
np.random.seed(42)
data = np.random.binomial(n=1,p=0.5,size=5000)
sns.countplot(x=data , hue=data)
print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.5
# Var : 0.25
# Std : 0.5
# Median : 0.5
# Mode : ModeResult(mode=np.int32(0), count=np.int64(2500))

# %%
# p = 0.5, size = 50000
# Out:
# Mean: 0.49894
# Var: 0.24999887639999996
# Std: 0.49999887639873747
# Median: 0.0
# Mode: ModeResult(mode=array([0]), count=array([25053]))

# %%
np.random.seed(42)
data = np.random.binomial(n=1,p=0.5,size=5000)
sns.histplot(x=data , hue=data)
print(f"Mean : {data.mean()}")
print(f"Var : {data.var()}")
print(f"Std : {data.std()}")
print(f"Median : {np.median(data)}")
print(f"Mode : {st.mode(data)}")
# Out:
# Mean : 0.5
# Var : 0.25
# Std : 0.5
# Median : 0.5
# Mode : ModeResult(mode=np.int32(0), count=np.int64(2500))

# %% [markdown]
# ## Binomial

# %% [markdown]
# - Consider a random experiment of tossing a <b>biased coin 6 times</b> where the <b>probability of getting a head is 0.6</b>.
# - If <b>‘getting a head’</b> is considered as <b>‘success’</b>.
# - Find the probability of <b>k</b> successes for each possible value of <b>k</b>. In other words, find probability of having 0 head, 1 head, 2 heads ... etc.
# - What is the mean and variance of this distribution? <b>(use binom.stats)</b>
# - Using <b>sns.barplot()</b> or any method of your choice to plot the probability distribution.
# - Generate the sample data using <b>np.random.binomial()</b> to obtain the same distribution and compare the results (try size=50 , 1000, and 10000).
# - Repeat with p=0.1 and p=0.9
# - Repeat with n = 1000, p=0.6 (you can also try with any <b>p</b>)

# %%
mean, var= binom.stats(n=6, p=0.6, moments='mv')
x_arr = np.arange(0, 7) #Number of success in each experiment
p_arr = binom.pmf(x_arr,n=6,p=0.6)

for i,item in enumerate(p_arr):
    print(f'P({i}): {p_arr[i]} ')

print(f'Mean : {mean}')
print(f'Var : {var}')
# Out:
# P(0): 0.004096000000000002
# P(1): 0.03686400000000002
# P(2): 0.13824000000000009
# P(3): 0.27648000000000017
# P(4): 0.3110400000000001
# P(5): 0.1866240000000001
# P(6): 0.046655999999999996
# Mean : 3.5999999999999996
# Var : 1.4399999999999995

# %%
## biased coin throw 6 times
## Number of heads n = 6 , k= 0,1,2,3,4,5,6
# Out:
# P(0): 0.0040960000000000015
# P(1): 0.03686400000000002
# P(2): 0.1382400000000001
# P(3): 0.2764800000000001
# P(4): 0.3110400000000001
# P(5): 0.1866240000000001
# P(6): 0.04665599999999999
# Mean: 3.5999999999999996
# Var.: 1.44

# %%
sns.barplot(x=x_arr,y=p_arr,hue=x_arr)
# Out:
# <Axes: >

# %%
sns.barplot(x=x_arr,y=p_arr,hue=x_arr)
# Out:
# <Axes: >

# %%
# Out:
# <AxesSubplot:>

# %%
mean, var= binom.stats(n=6, p=0.6, moments='mv')
x_arr = np.arange(0, 7) #Number of success 
p_arr = binom.pmf(x_arr,n=6,p=0.6)

for i,item in enumerate(p_arr):
    print(f'P({i}): {p_arr[i]} ')

print(f'Mean : {mean}')
print(f'Var : {var}')

# %%
# size = 50
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=50)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
# Out:
# Mean: 3.82
# Var : 1.4676
# <Axes: ylabel='Proportion'>

# %%
# Out:
# Mean: 3.82
# Var: 1.4676

# %%
# size = 50
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=50)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.countplot(x=data,hue=data)
# Out:
# Mean: 3.82
# Var : 1.4676
# <Axes: ylabel='count'>

# %%
# size = 1000
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=1000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
# Out:
# Mean: 3.642
# Var : 1.4598360000000001
# <Axes: ylabel='Proportion'>

# %%
# size = 1000
# Out:
# Mean: 3.642
# Var: 1.4598360000000001

# %%
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=1000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.countplot(x=data,hue=data)
# Out:
# Mean: 3.642
# Var : 1.4598360000000001
# <Axes: ylabel='count'>

# %%
# size = 10000
# Out:
# Mean: 3.623
# Var: 1.414271

# %%
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=10000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.countplot(x=data,hue=data)
# Out:
# Mean: 3.623
# Var : 1.4142709999999998
# <Axes: ylabel='count'>

# %%
# size = 1000
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=10000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
# Out:
# Mean: 3.623
# Var : 1.4142709999999998
# <Axes: ylabel='Proportion'>

# %%
# p=0.1

mean, var= binom.stats(n=6, p=0.1, moments='mv')
x_arr = np.arange(0, 7) #Number of success 
p_arr = binom.pmf(x_arr,n=6,p=0.6)

for i,item in enumerate(p_arr):
    print(f'P({i}): {p_arr[i]} ')

print(f'Mean : {mean}')
print(f'Var : {var}')
# Out:
# P(0): 0.004096000000000002
# P(1): 0.03686400000000002
# P(2): 0.13824000000000009
# P(3): 0.27648000000000017
# P(4): 0.3110400000000001
# P(5): 0.1866240000000001
# P(6): 0.046655999999999996
# Mean : 0.6000000000000001
# Var : 0.54

# %%
# p=0.1
# Out:
# P(0): 0.531441
# P(1): 0.35429399999999994
# P(2): 0.09841500000000003
# P(3): 0.014580000000000004
# P(4): 0.0012150000000000004
# P(5): 5.4000000000000005e-05
# P(6): 1.0000000000000004e-06
# Mean: 0.6000000000000001
# Var.: 0.5400000000000001
# size = 50
# Mean: 0.48
# Var: 0.44959999999999994
# size = 1000
# Mean: 0.602
# Var: 0.557596
# size = 10000
# Mean: 0.5846
# Var: 0.5242428400000001

# %%
np.random.seed(42)
data=np.random.binomial(n=6,p=0.1,size=50)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()

np.random.seed(42)
data=np.random.binomial(n=6,p=0.1,size=1000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()


np.random.seed(42)
data=np.random.binomial(n=6,p=0.1,size=10000)
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
# Out:
# Mean: 0.48
# Var : 0.44959999999999994
# Mean: 0.602
# Var : 0.557596
# Mean: 0.5846
# Var : 0.5242428400000001

# %%
mean, var= binom.stats(n=6, p=0.9, moments='mv')
x_arr = np.arange(0, 7) #Number of success 
p_arr = binom.pmf(x_arr,n=6,p=0.6)

for i,item in enumerate(p_arr):
    print(f'P({i}): {p_arr[i]} ')

print(f'Mean : {mean}')
print(f'Var : {var}')
# Out:
# P(0): 0.004096000000000002
# P(1): 0.03686400000000002
# P(2): 0.13824000000000009
# P(3): 0.27648000000000017
# P(4): 0.3110400000000001
# P(5): 0.1866240000000001
# P(6): 0.046655999999999996
# Mean : 5.4
# Var : 0.54

# %%
np.random.seed(42)
data=np.random.binomial(n=6,p=0.9,size=50)
print("Size 50")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()

np.random.seed(42)
data=np.random.binomial(n=6,p=0.9,size=1000)
print("Size 1000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()


np.random.seed(42)
data=np.random.binomial(n=6,p=0.9,size=10000)
print("Size 10000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
# Out:
# Size 50
# Mean: 5.52
# Var : 0.44959999999999994
# Size 1000
# Mean: 5.398
# Var : 0.557596
# Size 10000
# Mean: 5.4154
# Var : 0.5242428400000001

# %%
# p=0.9

# %%
np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=50)
print("Size = 50")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
sns.countplot(x=data,hue=data)
plt.show()

np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=1000)
print("Size = 1000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
plt.show()
sns.countplot(x=data,hue=data)
plt.show()

np.random.seed(42)
data=np.random.binomial(n=6,p=0.6,size=10000)
print("Size = 10000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
sns.countplot(x=data,hue=data)
plt.show()
# Out:
# Size = 50
# Mean: 3.82
# Var : 1.4676
# Size = 1000
# Mean: 3.642
# Var : 1.4598360000000001
# Size = 10000
# Mean: 3.623
# Var : 1.4142709999999998

# %%
mean, var= binom.stats(n=1000, p=0.6, moments='mv')
x_arr = np.arange(0, 999) #Number of success 
p_arr = binom.pmf(x_arr,n=6,p=0.6)

# for i,item in enumerate(p_arr):
#     print(f'P({i}): {p_arr[i]} ')

print(f'Mean : {mean}')
print(f'Var : {var}')
# Out:
# Mean : 600.0
# Var : 240.0

# %%
# p=0.6, n=1000

# size = 50

# size = 1000

# size = 10000

np.random.seed(42)
data=np.random.binomial(n=1000,p=0.6,size=50)
print("Size = 50")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
# sns.barplot(x=data,stat="proportion")
plt.show()
sns.histplot(x=data,stat="proportion")
plt.show()
sns.countplot(x=data,hue=data)
plt.show()

np.random.seed(42)
data=np.random.binomial(n=1000,p=0.6,size=1000)
print("Size = 1000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
plt.show()
sns.countplot(x=data,hue=data)
plt.show()

np.random.seed(42)
data=np.random.binomial(n=1000,p=0.6,size=10000)
print("Size = 10000")
print(f'Mean: {data.mean()}')
print(f'Var : {data.var()}')
sns.histplot(x=data,stat="proportion")
plt.show()
sns.countplot(x=data,hue=data)
plt.show()
# Out:
# Size = 50
# Mean: 601.8
# Var : 247.55999999999997
# Size = 1000
# Mean: 600.714
# Var : 256.482204
# Size = 10000
# Mean: 600.0494
# Var : 244.98075964

# %% [markdown]
# ## Normal (Gaussian) Distribution
# - Most graduate schools of business require applicants for admission to take the Graduate Management Admission Council’s GMAT examination.
# - Scores on the GMAT are roughly normally distributed with a mean of <b>527</b> and a standard deviation of <b>112</b>.
# - Plot the <b>pdf</b> and <b>cdf</b> with the given parameters. <b>(you can use scipy.stats.norm.pdf() and scipy.stats.norm.cdf()) </b>
# - Use <b>numpy.random.normal()</b> to Generate random sample with the given parameters. <b>(Use sample size = 10000)</b>
# - Compute <b>mean</b> and <b>variance</b> for the generated data and compare with the original parameters.
# - Plot the <b>distribution</b> for the generated data.
#
# #### Answer the following question:
# - What is the probability of an individual scoring above 500 on the GMAT?
# ##### You must answer the above questions with all of the following methods:
# 1. Using <b>scipy.stats.norm.cdf()</b> with the distribution parameters.
# 2. Convert the the given score <b>(e.g., 500)</b> to a <b>z-score</b> and find the answer from the <b>z-table</b>.
# 3. Use the <b>z-score</b> and use <b>scipy.stats.norm.cdf()</b> to obtain the result.
# 4. Use the generated data sample.
# 5. Convert the generated data sample to stabdard normal distribution (using <b>scipy.stats.zscore()</b>) then calculate the result.
#
# ##### Use any way you want to answer the following question:
# - How high must an individual score on the GMAT in order to score in the highest 5%? (<b>scipy.stats.norm.ppf() is useful in this case</b>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mean = 527
std = 112
size = 10000

data = np.random.normal(mean, std, size=size)

x = np.linspace(mean - 4*std, mean + 4*std, 1000)

pdf = norm.pdf(x, mean, std)
cdf = norm.cdf(x, mean, std)

top5 = norm.ppf(0.95, mean, std)

print(f"Mean: {mean}")
print(f"Variance: {std**2}")
print(f"Highest 5% score: {top5:.0f}")

plt.figure(figsize=(12,5))
plt.plot(x, pdf, color='blue', label='Theoretical PDF')
plt.show()

plt.figure(figsize=(12,5))
plt.plot(x, cdf, color='purple')
plt.legend()
plt.show()
# Out:
# Mean: 527
# Variance: 12544
# Highest 5% score: 711
# C:\Users\hazem\AppData\Local\Temp\ipykernel_41880\2165152971.py:34: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.plot()

# %%
# Out:
# mean: 527.0
# var: 12544.0

# %%
sns.histplot(data, bins=50,kde=True)
plt.show() #affects normal dist , prob of success and sample siza

# %% [markdown]
# ##### What is the probability of an individual scoring above 500 on the GMAT?

# %%
# Using scipy.stats.norm.cdf()
mean = 527
std = 112
p_above_500 = 1 - norm.cdf(500, mean, std)
print(p_above_500)
# Out:
# 0.5952501217429682

# %%
# Out:
# Probability of an individual scoring above 500 on the GMAT:
# 0.5952501217429682

# %%
z = (500 - mean)/std
print(z)
# Out:
# -0.24107142857142858

# %%
# Out:
# Z-score: -0.24107142857142858

# %%
z = (500 - mean) / std
print(f"Z-score: {z}")
#P(X>500)=1−P(Z<−0.24)=1−0.405=0.595
# Out:
# Z-score: -0.24107142857142858

# %%
# from z-table
# Out:
# 0.59483

# %%
# Use the z-score and use scipy.stats.norm.cdf() to obtain the result.
p_above_500 = 1 - norm.cdf(z)
print(p_above_500)
# Out:
# 0.5952501217429682

# %%
# Out:
# Probability of an individual scoring above 500 on the GMAT:
# 0.5952501217429682

# %%
# Use the generated data sample.
p_above_500 = np.mean(data > 500)
print(p_above_500)
# Out:
# 0.5962

# %%
# Out:
# Probability of an individual scoring above 500 on the GMAT:
# 0.5952

# %%
z_data = zscore(data)
z_500 = (500 - mean) / std
p_above_500 = np.mean(z_data > z_500)
print(p_above_500)
# Out:
# 0.5931

# %%
# Out:
# Probability of an individual scoring above 500 on the GMAT:
# 0.5963

# %% [markdown]
# ##### How high must an individual score on the GMAT in order to score in the highest 5%?

# %%
print(st.norm.ppf(0.95,mean,std))
# Out:
# 711.2236062185649

# %%
# Out:
# Above: 711.2236062185649
